# %% [markdown]
# # Time Series Analysis in Python – A Comprehensive Guide with Examples

# %% [markdown]
# ## 1. What is a Time Series

# %% [markdown]
# Time series is a sequence of observations recorded at regular time intervals.

# %% [markdown]
# ## 2. How to import Time Series in Python?

# %%
from dateutil.parser import parse
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# Import as DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'])
df.head()
# Out:
#         date     value
# 0 1991-07-01  3.526591
# 1 1991-08-01  3.180891
# 2 1991-09-01  3.252221
# 3 1991-10-01  3.611003
# 4 1991-11-01  3.565869

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    204 non-null    datetime64[ns]
#  1   value   204 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.3 KB

# %%
ser = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')
ser.head()
# Out:
#                value
# date
# 1991-07-01  3.526591
# 1991-08-01  3.180891
# 1991-09-01  3.252221
# 1991-10-01  3.611003
# 1991-11-01  3.565869

# %% [markdown]
# ## 3. What is Panel Data?

# %% [markdown]
# Panel data is also a time based dataset.

# %% [markdown]
# The difference is that, in addition to time series, it also contains one or more related variables that are measured for the same time periods.

# %% [markdown]
# Typically, the columns present in panel data contain explanatory variables that can be helpful in predicting the Y, provided those columns will be available at the future forecasting period.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/MarketArrivals.csv')
df.head()
# Out:
#        market    month  year  quantity  ...  priceMod  state    city          date
# 0  ABOHAR(PB)  January  2005      2350  ...       446     PB  ABOHAR  January-2005
# 1  ABOHAR(PB)  January  2006       900  ...       563     PB  ABOHAR  January-2006
# 2  ABOHAR(PB)  January  2010       790  ...      1460     PB  ABOHAR  January-2010
# 3  ABOHAR(PB)  January  2011       245  ...      3433     PB  ABOHAR  January-2011
# 4  ABOHAR(PB)  January  2012      1035  ...       605     PB  ABOHAR  January-2012
#
# [5 rows x 10 columns]

# %%
df.loc[df['market'] == 'MUMBAI'].head()
# Out:
#       market    month  year  quantity  ...  priceMod  state    city          date
# 6654  MUMBAI  January  2004    267100  ...       849     MS  MUMBAI  January-2004
# 6655  MUMBAI  January  2005    275845  ...       387     MS  MUMBAI  January-2005
# 6656  MUMBAI  January  2006    228000  ...       402     MS  MUMBAI  January-2006
# 6657  MUMBAI  January  2007    205200  ...       997     MS  MUMBAI  January-2007
# 6658  MUMBAI  January  2008    267550  ...       448     MS  MUMBAI  January-2008
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 4. Visualizing Time Series

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# Draw plot
def plot_df(df, x, y, title='', xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16, 5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, df.index, df.value, title='Monthly anti-diabetic drug sales in Australia from 1992 to 2008.')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')
x = df.index
y = df.values.reshape(-1)

print(y.shape)
print(x.shape)

# Plot
fig, ax = plt.subplots(1, 1, figsize=(16, 5), dpi=120)
plt.fill_between(x, y1=y, y2=-y, alpha=0.5, linewidth=2, color='seagreen')
plt.title('Monthly anti-diabetic drug sales (Two side view)', fontsize=16)
plt.hlines(y=0, xmin=np.min(df.index), xmax=np.max(df.index), linewidth=0.5)
plt.show()
# Out:
# (204,)
# (204,)

# %%
# Import data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'])

# Prepare data
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
years = df['year'].unique()

# Prep colors
np.random.seed(100)
mycolors = np.random.choice(list(mpl.colors.XKCD_COLORS.keys()), size=len(years))

# Draw plot
plt.figure(figsize=(16, 10), dpi=80)
for i, y in enumerate(years):
    plt.plot('month', 'value', data=df.loc[df.year == y, :], color=mycolors[i], label=y)
    plt.text(df.loc[df.year == y, :].shape[0]-.9, df.loc[df.year==y, 'value'][-1:].values[0], y, fontsize=12, color=mycolors[i])

# Decoration
plt.gca().set(xlim=(-0.3, 11), ylim=(2, 30), ylabel='$Drug Sales$', xlabel='$Month$')
plt.yticks(fontsize=12, alpha=.7)
plt.title("Seasonal Plot of Drug Sales Time Series", fontsize=20)
plt.show()
